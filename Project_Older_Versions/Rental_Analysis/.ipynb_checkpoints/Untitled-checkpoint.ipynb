# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
historical_rent = pd.read_excel(r"C:\Users\igsuw\OneDrive\Documents\GitHub\Data_Portfolio\Vancouver_Rental_Analysis\Dataset\Historical Data\Historical_Median_Rent_by_Bedroom_Type.xlsx")
historical_units = pd.read_excel(r"C:\Users\igsuw\OneDrive\Documents\GitHub\Data_Portfolio\Vancouver_Rental_Analysis\Dataset\Historical Data\Historical_Units_by_Bedroom_Type.xlsx")
zone_rent = pd.read_excel(r"C:\Users\igsuw\OneDrive\Documents\GitHub\Data_Portfolio\Vancouver_Rental_Analysis\Dataset\Zone Data\Zone_Rent_by_Bedroom_Type.xlsx")
zone_units = pd.read_excel(r"C:\Users\igsuw\OneDrive\Documents\GitHub\Data_Portfolio\Vancouver_Rental_Analysis\Dataset\Zone Data\Zone_Units_by_Bedroom_Type.xlsx")
wage = pd.read_excel(r"C:\Users\igsuw\OneDrive\Documents\GitHub\Data_Portfolio\Vancouver_Rental_Analysis\Dataset\Wage\Combined_Wage_Data.xlsx")

# %%
historical_rent
# Out:
#     Year  Bachelor  1_Bedroom  2_Bedroom  3_Plus_Bedroom  Total_Median_Rent
# 0   2004       660        750        895            1050                775
# 1   2005       680        760        900            1090                795
# 2   2006       700        780        950            1100                815
# 3   2007       738        800        973            1140                845
# 4   2008       750        850       1011            1200                880
# 5   2009       785        875       1064            1298                900
# 6   2010       802        900       1100            1300                930
# 7   2011       820        905       1110            1325                950
# 8   2012       850        935       1150            1334                975
# 9   2013       875        950       1175            1374               1000
# 10  2014       900        995       1200            1375               1035
# 11  2015       922       1010       1250            1450               1073
# 12  2016       975       1085       1305            1500               1150
# 13  2017      1010       1165       1400            1600               1213
# 14  2018      1100       1250       1519            1703               1300
# 15  2019      1200       1350       1600            1800               1400
# 16  2020      1250       1390       1650            1850               1436
# 17  2021      1300       1400       1720            1952               1475
# 18  2022      1345       1500       1900            2100               1575
# 19  2023      1424       1640       2100            2350               1715

# %%
historical_units.head()
# Out:
#    Year  Bachelor  1_Bedroom  2_Bedroom  3_Plus_Bedroom  Total_Units
# 0  2004     12130      66537      26324            4742       109733
# 1  2005     12197      66778      26341            4626       109942
# 2  2006     11999      65688      25950            4579       108216
# 3  2007     11885      65386      25753            4222       107246
# 4  2008     11543      65100      25465            4287       106395

# %%
zone_rent.head()
# Out:
#                     Zone  Bachelor  1_Bedroom  2_Bedroom  3_Plus_Bedroom  \
# 0  West End/Stanley Park    1345.0       1750       2328          3095.0
# 1            English Bay    1434.0       1939       2995             NaN
# 2               Downtown    1693.0       2100       3000             NaN
# 3    South Granville/Oak    1347.0       1652       2182             NaN
# 4   Kitsilano/Point Grey    1438.0       1715       2557          3650.0
#
#    Total_Median_Rent
# 0               1750
# 1               1925
# 2               2100
# 3               1691
# 4               1810

# %%
zone_units.head()
# Out:
#                     Zone  Bachelor  1_Bedroom  2_Bedroom  3_Plus_Bedroom  \
# 0  West End/Stanley Park       682       2693        500              35
# 1            English Bay       895       5182        752              35
# 2               Downtown      2449       7974       1732              96
# 3    South Granville/Oak      1791       5388       1729             109
# 4   Kitsilano/Point Grey       912       5095       1446              89
#
#    Total_Units
# 0         3910
# 1         6864
# 2        12251
# 3         9017
# 4         7542

# %%
wage.head()
# Out:
#    Year  Med_Wage  Min_Wage
# 0  2004     17.79       8.0
# 1  2005     18.00       8.0
# 2  2006     18.10       8.0
# 3  2007     19.02       8.0
# 4  2008     20.00       8.0

# %%
plt.plot(historical_rent['Year'], historical_rent['Total_Median_Rent'])
plt.xticks(np.arange(min(historical_rent['Year']), max(historical_rent['Year'])+1, 1.0))
plt.show()

# %%
historical_rent['Total_Median_Rent'].corr(historical_units['Total_Units'])
# Out:
# 0.9253234093147069

# %%
plt.scatter(historical_rent['Total_Median_Rent'], historical_units['Total_Units'])
plt.show()

# %%
wage['Monthly_Med_Wage'], wage['Monthly_Min_Wage']= (wage['Med_Wage'] * 30 * 4), (wage['Min_Wage'] * 30 * 4 )

# %%
wage['Med_Percent']= historical_rent['Total_Median_Rent']/wage['Monthly_Med_Wage']*100
wage['Min_Percent']= historical_rent['Total_Median_Rent']/wage['Monthly_Min_Wage']*100

# %%
wage
# Out:
#     Year  Med_Wage  Min_Wage  Monthly_Med_Wage  Monthly_Min_Wage  Med_Percent  \
# 0   2004     17.79      8.00            2134.8             960.0    36.303167
# 1   2005     18.00      8.00            2160.0             960.0    36.805556
# 2   2006     18.10      8.00            2172.0             960.0    37.523020
# 3   2007     19.02      8.00            2282.4             960.0    37.022433
# 4   2008     20.00      8.00            2400.0             960.0    36.666667
# 5   2009     20.19      8.00            2422.8             960.0    37.147103
# 6   2010     21.00      8.00            2520.0             960.0    36.904762
# 7   2011     21.00      9.50            2520.0            1140.0    37.698413
# 8   2012     21.49     10.25            2578.8            1230.0    37.808283
# 9   2013     22.00     10.25            2640.0            1230.0    37.878788
# 10  2014     22.00     10.25            2640.0            1230.0    39.204545
# 11  2015     23.00     10.45            2760.0            1254.0    38.876812
# 12  2016     23.00     10.85            2760.0            1302.0    41.666667
# 13  2017     23.48     11.35            2817.6            1362.0    43.050823
# 14  2018     24.00     12.65            2880.0            1518.0    45.138889
# 15  2019     25.00     13.85            3000.0            1662.0    46.666667
# 16  2020     26.25     14.60            3150.0            1752.0    45.587302
# 17  2021     27.00     15.20            3240.0            1824.0    45.524691
# 18  2022     28.00     15.65            3360.0            1878.0    46.875000
# 19  2023     30.00     16.75            3600.0            2010.0    47.638889
#
#     Min_Percent
# 0     80.729167
# 1     82.812500
# 2     84.895833
# 3     88.020833
# 4     91.666667
# 5     93.750000
# 6     96.875000
# 7     83.333333
# 8     79.268293
# 9     81.300813
# 10    84.146341
# 11    85.566188
# 12    88.325653
# 13    89.060206
# 14    85.638999
# 15    84.235860
# 16    81.963470
# 17    80.866228
# 18    83.865815
# 19    85.323383

# %%
plt.bar(zone_rent['Zone'], zone_rent['Total_Median_Rent'])
# Out:
# <BarContainer object of 26 artists>
